# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

dc_data = "/Users/datki/Desktop/DC_data/DC_Properties.csv"

# %%
df = pd.read_csv(dc_data)
df.head()
# Out:
# C:\Users\datki\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3020: DtypeWarning: Columns (18,19,20,21,22,23,24,33,34,35,37,43,45) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    Unnamed: 0  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  BEDRM  \
# 0           0       4          0      Warm Cool  Y        2.0      8      4
# 1           1       3          1      Warm Cool  Y        2.0     11      5
# 2           2       3          1  Hot Water Rad  Y        2.0      9      5
# 3           3       3          1  Hot Water Rad  Y        2.0      8      5
# 4           4       2          1      Warm Cool  Y        1.0     11      3
#
#       AYB  YR_RMDL   ...     LONGITUDE  ASSESSMENT_NBHD ASSESSMENT_SUBNBHD  \
# 0  1910.0   1988.0   ...    -77.040832       Old City 2   040 D Old City 2
# 1  1898.0   2007.0   ...    -77.040764       Old City 2   040 D Old City 2
# ...

# %%
isolated_pd = df.drop(columns=["Unnamed: 0", "BATHRM", "HF_BATHRM", "HEAT", "AC", "NUM_UNITS", 
                                                "ROOMS", "BEDRM", "AYB", "YR_RMDL", "EYB", "STORIES", "SALE_NUM", 
                                                "BLDG_NUM", "GRADE", "CNDTN", "EXTWALL", "ROOF", "INTWALL",
                                                "KITCHENS", "FIREPLACES", "USECODE", "GIS_LAST_MOD_DTTM",
                                                "CMPLX_NUM", "ASSESSMENT_NBHD", "ASSESSMENT_SUBNBHD", 
                                                "CENSUS_TRACT", "CENSUS_BLOCK", "QUADRANT", "X", "Y"])
isolated_pd.head()
# Out:
#               SALEDATE      PRICE QUALIFIED     GBA    STYLE         STRUCT  \
# 0  2003-11-25 00:00:00  1095000.0         Q  2522.0  3 Story     Row Inside
# 1  2000-08-17 00:00:00        NaN         U  2567.0  3 Story     Row Inside
# 2  2016-06-21 00:00:00  2100000.0         Q  2522.0  3 Story     Row Inside
# 3  2006-07-12 00:00:00  1602000.0         Q  2484.0  3 Story     Row Inside
# 4                  NaN        NaN         U  5255.0  3 Story  Semi-Detached
#
#    LANDAREA       SOURCE  LIVING_GBA                   FULLADDRESS  \
# 0      1680  Residential         NaN          1748 SWANN STREET NW
# 1      1680  Residential         NaN          1746 SWANN STREET NW
# 2      1680  Residential         NaN          1744 SWANN STREET NW
# 3      1680  Residential         NaN          1742 SWANN STREET NW
# 4      2032  Residential         NaN  1804 NEW HAMPSHIRE AVENUE NW
#
#          CITY STATE  ZIPCODE        NATIONALGRID   LATITUDE  LONGITUDE  \
# ...

# %%
final_df= df.loc[df['QUALIFIED']=='Q']
final_df.plot.scatter(x='GBA', y='PRICE')

# %%
new_df = isolated_pd.fillna(0)
new_df.head()
# Out:
#               SALEDATE      PRICE QUALIFIED     GBA    STYLE         STRUCT  \
# 0  2003-11-25 00:00:00  1095000.0         Q  2522.0  3 Story     Row Inside
# 1  2000-08-17 00:00:00        0.0         U  2567.0  3 Story     Row Inside
# 2  2016-06-21 00:00:00  2100000.0         Q  2522.0  3 Story     Row Inside
# 3  2006-07-12 00:00:00  1602000.0         Q  2484.0  3 Story     Row Inside
# 4                    0        0.0         U  5255.0  3 Story  Semi-Detached
#
#    LANDAREA       SOURCE  LIVING_GBA                   FULLADDRESS  \
# 0      1680  Residential         0.0          1748 SWANN STREET NW
# 1      1680  Residential         0.0          1746 SWANN STREET NW
# 2      1680  Residential         0.0          1744 SWANN STREET NW
# 3      1680  Residential         0.0          1742 SWANN STREET NW
# 4      2032  Residential         0.0  1804 NEW HAMPSHIRE AVENUE NW
#
#          CITY STATE  ZIPCODE        NATIONALGRID   LATITUDE  LONGITUDE  \
# ...

# %%
new_data = new_df[new_df.PRICE != 0]
new_data.head()
# Out:
#               SALEDATE      PRICE QUALIFIED     GBA    STYLE      STRUCT  \
# 0  2003-11-25 00:00:00  1095000.0         Q  2522.0  3 Story  Row Inside
# 2  2016-06-21 00:00:00  2100000.0         Q  2522.0  3 Story  Row Inside
# 3  2006-07-12 00:00:00  1602000.0         Q  2484.0  3 Story  Row Inside
# 5  2010-02-26 00:00:00  1950000.0         Q  5344.0  4 Story  Row Inside
# 7  2011-09-29 00:00:00  1050000.0         Q  2401.0  3 Story  Row Inside
#
#    LANDAREA       SOURCE  LIVING_GBA           FULLADDRESS        CITY STATE  \
# 0      1680  Residential         0.0  1748 SWANN STREET NW  WASHINGTON    DC
# 2      1680  Residential         0.0  1744 SWANN STREET NW  WASHINGTON    DC
# 3      1680  Residential         0.0  1742 SWANN STREET NW  WASHINGTON    DC
# 5      2196  Residential         0.0      1709 S STREET NW  WASHINGTON    DC
# 7      1627  Residential         0.0  1746 1/2 T STREET NW  WASHINGTON    DC
#
# ...

# %%
year = new_data['SALEDATE']
price_data = new_data['PRICE']
plt.scatter(year, price_data, edgecolors='r')
plt.xlabel('SALEDATE')
plt.ylabel('PRICE')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-69c80e025d9b> in <module>
#       1 year = new_data['SALEDATE']
#       2 price_data = new_data['PRICE']
# ----> 3 plt.scatter(year, price_data, edgecolors='r')
#       4 plt.xlabel('SALEDATE')
#       5 plt.ylabel('PRICE')
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, data, **kwargs)
#    2862         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
#    2863         verts=verts, edgecolors=edgecolors, **({"data": data} if data
# -> 2864         is not None else {}), **kwargs)
#    2865     sci(__ret)
#    2866     return __ret
#
# ~\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
# ...

# %%
style_data = new_data["STYLE"]
price_data = new_data["PRICE"]
colors = ["#1f77b4", "#ff7f0e", "#2ca02c", "#d62728", "#8c564b"]
explode = (0.1, 0, 0, 0, 0)  
plt.pie(price_data, labels=style_data, explode=None, colors=None,
autopct='%1.1f%%', shadow=True, startangle=140)
plt.axis("equal")
# Save an image of our chart and print the final product to the screen
plt.savefig("../PyPies.png")
plt.show()
